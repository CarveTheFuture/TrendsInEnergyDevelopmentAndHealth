# %%
import numpy as numpy
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("data.csv")

# %%
data.columns = [c.replace(' ', '_') for c in data.columns]

# %%
data
# Out:
#       Country_Name Country_Code  \
# 0       Arab World          ARB
# 1       Arab World          ARB
# 2       Arab World          ARB
# 3       Arab World          ARB
# 4       Arab World          ARB
# ...            ...          ...
# 89005     Zimbabwe          ZWE
# 89006     Zimbabwe          ZWE
# 89007     Zimbabwe          ZWE
# 89008     Zimbabwe          ZWE
# 89009     Zimbabwe          ZWE
#
#                                           Indicator_Name     Indicator_Code  \
# 0      % of females ages 15-49 having comprehensive c...  SH.HIV.KNOW.FE.ZS
# 1      % of males ages 15-49 having comprehensive cor...  SH.HIV.KNOW.MA.ZS
# 2      Adolescent fertility rate (births per 1,000 wo...        SP.ADO.TFRT
# 3      Adults (ages 15+) and children (0-14 years) li...        SH.HIV.TOTL
# 4      Adults (ages 15+) and children (ages 0-14) new...     SH.HIV.INCD.TL
# ...                                                  ...                ...
# ...

# %%
newdf = data[data.Indicator_Code.isin(["SH.XPD.PCAP", "SH.H20.SAFE.ZS","SH.STA.BRTC.ZS","SH.DTH.COMM.ZS","SH.DTH.INJR.ZS","SP.RUR.TOTL.ZS"])]

# %% [markdown]
# https://www.listendata.com/2019/07/how-to-filter-pandas-dataframe.html#:~:text=%20Filter%20pandas%20dataframe%20by%20column%20value%20,same%20output.%20It%27s%20just%20a%20different...%20More%20

# %%
health_expend_trans=data[data.Indicator_Code.isin(["SH.XPD.PCAP"])]

# %%
health_expend=health_expend_trans.transpose()

# %% [markdown]
# https://stackoverflow.com/questions/13757090/pandas-column-access-w-column-names-containing-spaces

# %%
health_expend_trans
# Out:
#                          Country_Name Country_Code  \
# 119                        Arab World          ARB
# 464            Caribbean small states          CSS
# 809    Central Europe and the Baltics          CEB
# 1154       Early-demographic dividend          EAR
# 1499              East Asia & Pacific          EAS
# ...                               ...          ...
# 87404           Virgin Islands (U.S.)          VIR
# 87749              West Bank and Gaza          WBG
# 88094                     Yemen, Rep.          YEM
# 88439                          Zambia          ZMB
# 88784                        Zimbabwe          ZWE
#
#                                     Indicator_Name Indicator_Code  1960  1961  \
# 119    Health expenditure per capita (current US$)    SH.XPD.PCAP   NaN   NaN
# 464    Health expenditure per capita (current US$)    SH.XPD.PCAP   NaN   NaN
# 809    Health expenditure per capita (current US$)    SH.XPD.PCAP   NaN   NaN
# ...

# %%
health_expend
# Out:
#                                                       119    \
# Country_Name                                     Arab World
# Country_Code                                            ARB
# Indicator_Name  Health expenditure per capita (current US$)
# Indicator_Code                                  SH.XPD.PCAP
# 1960                                                    NaN
# ...                                                     ...
# 2012                                                 326.13
# 2013                                                341.766
# 2014                                                356.113
# 2015                                                    NaN
# Unnamed:_60                                             NaN
#
#                                                       464    \
# Country_Name                         Caribbean small states
# Country_Code                                            CSS
# Indicator_Name  Health expenditure per capita (current US$)
# ...

# %%
health_expend_numbers=health_expend.drop(["Country_Code","Indicator_Name","Indicator_Code"], axis=0)

# %%
health_expend_numbers.columns=health_expend_numbers.iloc[0]

# %%
health_expend_numbers
# Out:
#                                     42.2753
# 2002                                             48.5096
# 2003                                             55.6126
# 2004                                              62.752
# 2005                                             72.1306
# 2006                                             84.8149
# 2007                                             104.244
# 2008                                              136.63
# 2009                                             161.541
# 2010                                             186.161
# 2011                                             231.904
# 2012                                             270.027
# 2013                                             303.185
# 2014                                             333.908
# 2015                                                 NaN
# Unnamed:_60                                          NaN
#
# ...

# %%
health_expend_numbers=health_expend_numbers.drop(["Country_Name"], axis=0)

# %%
health_expend_numbers["Arab World"]
# Out:
# 1960               NaN
# 1961               NaN
# 1962               NaN
# 1963               NaN
# 1964               NaN
# 1965               NaN
# 1966               NaN
# 1967               NaN
# 1968               NaN
# 1969               NaN
# 1970               NaN
# 1971               NaN
# 1972               NaN
# 1973               NaN
# 1974               NaN
# 1975               NaN
# 1976               NaN
# 1977               NaN
# 1978               NaN
# 1979               NaN
# 1980               NaN
# 1981               NaN
# 1982               NaN
# 1983               NaN
# 1984               NaN
# 1985               NaN
# 1986               NaN
# 1987               NaN
# 1988               NaN
# 1989               NaN
# 1990               NaN
# 1991               NaN
# 1992               NaN
# 1993               NaN
# 1994               NaN
# 1995           85.7496
# 1996           91.0568
# 1997           97.6629
# 1998           99.7594
# 1999           108.104
# ...

# %%
health_expend_numbers.plot(y=[	"Arab World",	"Caribbean small states",	"East Asia & Pacific",	"Euro area",	"Europe & Central Asia"], title="Health expenditure variation (in Us dollars) by world region from the 20th century to the 21st")
plt.xlabel('time (years)')
plt.ylabel('exoenditures ($)')
# Out:
# Text(0, 0.5, 'exoenditures ($)')

# %% [markdown]
# https://www.geeksforgeeks.org/python-pandas-dataframe-transpose/#:~:text=Pandas%20DataFrame.transpose%20%28%29%20function%20transpose%20index%20and%20columns,diagonal%20by%20writing%20rows%20as%20columns%20and%20vice-versa.

# %% [markdown]
# https://stackoverflow.com/questions/42128467/matplotlib-plot-multiple-columns-of-pandas-data-frame-on-the-bar-chart

# %%
row_years
# Out:
#                                                             69     \
# Country_Name                                           Arab World
# Country_Code                                                  ARB
# Indicator_Name  Births attended by skilled health staff (% of ...
# Indicator_Code                                     SH.STA.BRTC.ZS
# 1960                                                          NaN
# ...                                                           ...
# 2012                                                      78.2128
# 2013                                                          NaN
# 2014                                                          NaN
# 2015                                                          NaN
# Unnamed:_60                                                   NaN
#
#                                                             70     \
# Country_Name                                           Arab World
# ...

# %%
rural_percent_trans=data[data.Indicator_Code.isin(["SP.RUR.TOTL.ZS"])]

# %%
rural_percent_trans
# Out:
#                          Country_Name Country_Code  \
# 303                        Arab World          ARB
# 648            Caribbean small states          CSS
# 993    Central Europe and the Baltics          CEB
# 1338       Early-demographic dividend          EAR
# 1683              East Asia & Pacific          EAS
# ...                               ...          ...
# 87588           Virgin Islands (U.S.)          VIR
# 87933              West Bank and Gaza          WBG
# 88278                     Yemen, Rep.          YEM
# 88623                          Zambia          ZMB
# 88968                        Zimbabwe          ZWE
#
#                                  Indicator_Name  Indicator_Code       1960  \
# 303    Rural population (% of total population)  SP.RUR.TOTL.ZS  68.705166
# 648    Rural population (% of total population)  SP.RUR.TOTL.ZS  68.402510
# 993    Rural population (% of total population)  SP.RUR.TOTL.ZS  55.492079
# ...

# %%
rural_percent=rural_percent_trans.transpose()

# %%
rural_percent.columns=rural_percent.iloc[0]

# %%
rural_percent=rural_percent.drop(["Country_Code","Indicator_Name","Indicator_Code","Country_Name"], axis=0)

# %%
rural_percent.plot(y=[	"Arab World",	"Caribbean small states",	"East Asia & Pacific",	"Euro area",	"Europe & Central Asia"],title="Rural population as a percentage of the whole by world region from the 20th century to the 21st")
plt.xlabel('time (years)')
plt.ylabel('percentage (%)')
# Out:
# Text(0, 0.5, 'percentage (%)')

# %%
plt.show()

# %%
rural_percent["Arab World"]
# Out:
# Country_Name    Arab World
# 1960                   NaN
# 1961                   NaN
# 1962                   NaN
# 1963                   NaN
# 1964                   NaN
# 1965                   NaN
# 1966                   NaN
# 1967                   NaN
# 1968                   NaN
# 1969                   NaN
# 1970                   NaN
# 1971                   NaN
# 1972                   NaN
# 1973                   NaN
# 1974                   NaN
# 1975                   NaN
# 1976                   NaN
# 1977                   NaN
# 1978                   NaN
# 1979                   NaN
# 1980                   NaN
# 1981                   NaN
# 1982                   NaN
# 1983                   NaN
# 1984                   NaN
# 1985                   NaN
# 1986                   NaN
# 1987                   NaN
# 1988                   NaN
# 1989                   NaN
# 1990                   NaN
# 1991                   NaN
# 1992                   NaN
# ...
